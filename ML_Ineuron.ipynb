# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya29051998/Machine-Learning/blob/main/ML_Ineuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
 import numpy as np
 import seaborn as sns
 import matplotlib.pyplot as plt
 # %matplotlib inline

# %%
from sklearn.datasets import fetch_california_housing

# %%
fetch_california_housing()
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
carlifornia = fetch_california_housing()

# %%
print(carlifornia['DESCR'])
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# ...

# %%
carlifornia.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
print(carlifornia['data'])
# Out:
# [[   8.3252       41.            6.98412698 ...    2.55555556
#     37.88       -122.23      ]
#  [   8.3014       21.            6.23813708 ...    2.10984183
#     37.86       -122.22      ]
#  [   7.2574       52.            8.28813559 ...    2.80225989
#     37.85       -122.24      ]
#  ...
#  [   1.7          17.            5.20554273 ...    2.3256351
#     39.43       -121.22      ]
#  [   1.8672       18.            5.32951289 ...    2.12320917
#     39.43       -121.32      ]
#  [   2.3886       16.            5.25471698 ...    2.61698113
#     39.37       -121.24      ]]

# %%
print(carlifornia['feature_names'])
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
print(carlifornia['target'])
# Out:
# [4.526 3.585 3.521 ... 0.923 0.847 0.894]

# %%
#Lets Prepare the Data Frame
pd.DataFrame(carlifornia.data,columns=carlifornia.feature_names)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
dataset = pd.DataFrame(carlifornia.data,columns=carlifornia.feature_names)

# %%
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
dataset.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
#check Missing values
dataset.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
#EDA
dataset.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#
#             Latitude  Longitude
# MedInc     -0.079809  -0.015176
# HouseAge    0.011173  -0.108197
# AveRooms    0.106389  -0.027540
# AveBedrms   0.069721   0.013344
# Population -0.108785   0.099773
# AveOccup    0.002366   0.002476
# Latitude    1.000000  -0.924664
# Longitude  -0.924664   1.000000

# %%
sns.pairplot(dataset)

# %%
sns.set(rc={'figure.figsize':(15,8)}) #Increse size of heatmap
sns.heatmap(dataset.corr(),annot=True) #create heatmap
# Out:
# <Axes: >

# %%
plt.scatter(dataset['MedInc'],dataset['HouseAge'])
plt.xlabel('MedInc')
plt.ylabel('HouseAge')
plt.title('MedInc vs HouseAge')
plt.show()

# %%
plt.scatter(dataset['MedInc'],dataset['AveRooms'])
plt.xlabel('MedInc')
plt.ylabel('AveRooms')
plt.title('MedInc vs AveRooms')
plt.show()

# %%
sns.regplot(x='MedInc',y='HouseAge',data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='HouseAge'>

# %%
sns.regplot(x='MedInc',y='AveRooms',data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='AveRooms'>

# %%
sns.regplot(x='MedInc',y='AveOccup',data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='AveOccup'>

# %%
sns.regplot(x='MedInc',y='AveBedrms',data=dataset)
# Out:
# <Axes: xlabel='MedInc', ylabel='AveBedrms'>

# %%
sns.boxenplot(x='MedInc',data=dataset)
# Out:
# <Axes: xlabel='MedInc'>

# %%
sns.boxenplot(x='HouseAge',data=dataset)
# Out:
# <Axes: xlabel='HouseAge'>

# %%
from re import X
#Independent Feature and Dependent Fature
X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85

# %%
y
# Out:
# 0       -122.23
# 1       -122.22
# 2       -122.24
# 3       -122.25
# 4       -122.25
#           ...
# 20635   -121.09
# 20636   -121.21
# 20637   -121.22
# 20638   -121.32
# 20639   -121.24
# Name: Longitude, Length: 20640, dtype: float64

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude
# 5088   0.9809      19.0  3.187726   1.129964       726.0  2.620939     33.98
# 17096  4.2232      33.0  6.189696   1.086651      1015.0  2.377049     37.46
# 5617   3.5488      42.0  4.821577   1.095436      1044.0  4.331950     33.79
# 20060  1.6469      24.0  4.274194   1.048387      1686.0  4.532258     35.87
# 895    3.9909      14.0  4.608303   1.089350      2738.0  2.471119     37.54
# ...       ...       ...       ...        ...         ...       ...       ...
# 11284  6.3700      35.0  6.129032   0.926267       658.0  3.032258     33.78
# 11964  3.0500      33.0  6.868597   1.269488      1753.0  3.904232     34.02
# 5390   2.9344      36.0  3.986717   1.079696      1756.0  3.332068     34.03
# 860    5.7192      15.0  6.395349   1.067979      1777.0  3.178891     37.58
# 15795  2.5755      52.0  3.402576   1.058776      2619.0  2.108696     37.77
#
# [13828 rows x 7 columns]

# %%
y_train
# Out:
# 5088    -118.28
# 17096   -122.23
# 5617    -118.26
# 20060   -119.26
# 895     -121.96
#           ...
# 11284   -117.96
# 11964   -117.43
# 5390    -118.38
# 860     -121.96
# 15795   -122.42
# Name: Longitude, Length: 13828, dtype: float64

# %%
X_test
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude
# 20046  1.6812      25.0  4.192201   1.022284      1392.0  3.877437     36.06
# 3024   2.5313      30.0  5.039384   1.193493      1565.0  2.679795     35.14
# 15663  3.4801      52.0  3.977155   1.185877      1310.0  1.360332     37.80
# 20484  5.7376      17.0  6.163636   1.020202      1705.0  3.444444     34.28
# 9814   3.7250      34.0  5.492991   1.028037      1063.0  2.483645     36.62
# ...       ...       ...       ...        ...         ...       ...       ...
# 15316  1.3269      19.0  3.987578   1.153209      1190.0  2.463768     33.20
# 14772  2.7361      14.0  4.206612   0.983471      1224.0  3.371901     32.57
# 12870  3.8355      15.0  6.419753   1.039781      2626.0  3.602195     38.71
# 13476  4.3958      10.0  6.154506   1.013948      3528.0  3.785408     34.09
# 16123  2.7431      51.0  3.857143   1.002597       880.0  2.285714     37.78
#
# [6812 rows x 7 columns]

# %%
y_test
# Out:
# 20046   -119.01
# 3024    -119.46
# 15663   -122.44
# 20484   -118.72
# 9814    -121.93
#           ...
# 15316   -117.36
# 14772   -117.07
# 12870   -121.40
# 13476   -117.39
# 16123   -122.47
# Name: Longitude, Length: 6812, dtype: float64

# %%
#Feature Engineering Standardize the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler.fit_transform(X_train)
# Out:
# array([[-1.52169954, -0.75868455, -0.91813082, ..., -0.61496167,
#         -0.04014979, -0.78315293],
#        [ 0.18205382,  0.3523991 ,  0.30748451, ..., -0.36282305,
#         -0.05943619,  0.8475975 ],
#        [-0.17232772,  1.06666717, -0.25107784, ..., -0.33752194,
#          0.09515433, -0.87218816],
#        ...,
#        [-0.49518065,  0.59048846, -0.59192622, ...,  0.28366387,
#          0.01608523, -0.75972261],
#        [ 0.96816708, -1.07613702,  0.39144665, ...,  0.30198536,
#          0.0039722 ,  0.90383028],
#        [-0.68377427,  1.86029835, -0.83041358, ...,  1.03658993,
#         -0.08065717,  0.9928655 ]])

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[-1.15370815, -0.28250584, -0.50803348, ..., -0.03390865,
#          0.05921216,  0.19154848],
#        [-0.70700034,  0.11430975, -0.16215378, ...,  0.11702554,
#         -0.03549556, -0.23956945],
#        [-0.20842797,  1.86029835, -0.59583032, ..., -0.10544971,
#         -0.13983657,  1.0069237 ],
#        ...,
#        [-0.02167353, -1.07613702,  0.40141018, ...,  1.04269709,
#          0.03744641,  1.43335556],
#        [ 0.27275111, -1.47295261,  0.29311784, ...,  1.82964878,
#          0.0519346 , -0.73160623],
#        [-0.59570436,  1.78093523, -0.64482761, ..., -0.48060407,
#         -0.06665881,  0.99755157]])

# %%
##Model Train
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression
# Out:
# LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
##Print the coeeficient and intercept
print(regression.coef_)
# Out:
# [-0.38031225 -0.20703565  0.47298424 -0.27332778 -0.05532736  0.02850142
#  -1.91798124]

# %%
print(regression.intercept_)
# Out:
# -119.58509835117154

# %%
##Prediction for test Data
y_pred = regression.predict(X_test)

# %%
y_pred
# Out:
# array([-119.64580532, -119.02342843, -122.15639038, ..., -121.93454872,
#        -117.89051595, -121.86262641])

# %%
##Assumptions of linnear rigression
plt.scatter(y_test,y_pred)
plt.xlabel("y_test")
plt.ylabel("y_pred")
plt.show()

# %%
#residuals
residuals = y_test - y_pred

# %%
residuals
# Out:
# 20046    0.635805
# 3024    -0.436572
# 15663   -0.283610
# 20484   -0.360703
# 9814    -1.484957
#            ...
# 15316   -0.340847
# 14772   -0.564412
# 12870    0.534549
# 13476    0.500516
# 16123   -0.607374
# Name: Longitude, Length: 6812, dtype: float64

# %%
sns.displot(residuals,kind='kde')

# %%
##Scatter plot with prediction and residual
#Uniform Distribution
plt.scatter(y_pred,residuals)
plt.xlabel("y_pred")
plt.ylabel("residuals")
plt.show()

# %% [markdown]
# The data is uniformly distributed

# %%
#Performance Matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 0.4841796650816953
# 0.4308867417353548
# 0.6564196384443071

# %%
## R square and Adjusted R square
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.8922701690143686

# %%
#Adjusted R square

1- (1- score)*len(y_test-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.8921435025464255

# %%
#Ridge
from sklearn.linear_model import Ridge
ridge = Ridge()
ridge.fit(X_train,y_train)
y_pred = ridge.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
#
# Out:
# 0.89226701545416

# %%
#Lasso
from sklearn.linear_model import Lasso
lasso = Lasso()
lasso.fit(X_train,y_train)
y_pred = lasso.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.6088460527392454

# %%
#Elastic
from sklearn.linear_model import ElasticNet
elastic = ElasticNet()
elastic.fit(X_train,y_train)
y_pred = elastic.predict(X_test)
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.6328726186072396
